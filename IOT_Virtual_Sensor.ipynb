# %%
import paho.mqtt.client as mqtt
import random
import time

mqtt_username = "PQkWKAsbOzMXPTkVDjsDFCw"
mqtt_password = "q1OHgnEFCV0IoFGY/tkT/m9t"
mqtt_client_id = "PQkWKAsbOzMXPTkVDjsDFCw"
channel_id = "2483177"
write_api_key = "WP9SEAZENHZGU3RU"
mqtt_host = "mqtt3.thingspeak.com"
topic = f"channels/{channel_id}/publish"

# Sensor Value Ranges
temperature_range = (-50, 50)
humidity_range = (0, 100)
co2_range = (300, 2000)

# Function for generating random sensor data
def generate_sensor_data():
    temperature = random.uniform(*temperature_range)
    humidity = random.uniform(*humidity_range)
    co2 = random.uniform(*co2_range)
    return temperature, humidity, co2


def on_connect(client, userdata, flags, rc, properties=None):
    if rc == 0:
        print("Connected to MQTT Broker!")
    else:
        print("Failed to connect, return code %d\n", rc)

# Function to create and configure the MQTT client
def create_mqtt_client():
    client = mqtt.Client(mqtt_client_id)
    client.username_pw_set(username=mqtt_username, password=mqtt_password)
    client.on_connect = on_connect
    client.connect(mqtt_host, port=1883, keepalive=60)
    return client

# Function to publish sensor data
def publish_sensor_data(client, temperature, humidity, co2):
    payload = f"field1={temperature}&field2={humidity}&field3={co2}"
    client.publish(topic, payload)


def main():
    client = create_mqtt_client()
    client.loop_start() 
    try:
        while True:
            temperature, humidity, co2 = generate_sensor_data()
            publish_sensor_data(client, temperature, humidity, co2)
            print(f"Published data - Temperature: {temperature:.2f}, Humidity: {humidity:.2f}, CO2: {co2:.2f}")
            time.sleep(20)  
    except KeyboardInterrupt:
        print("Sensor simulation stopped")
        client.loop_stop() 
main()
# Out:
# Published data - Temperature: -37.65, Humidity: 42.16, CO2: 725.37
# Connected to MQTT Broker!
# Published data - Temperature: 20.07, Humidity: 72.58, CO2: 593.40
# Published data - Temperature: -27.95, Humidity: 85.90, CO2: 1709.61
# Published data - Temperature: 28.16, Humidity: 20.90, CO2: 987.74
# Published data - Temperature: -8.13, Humidity: 79.81, CO2: 384.55
# Published data - Temperature: -43.29, Humidity: 18.59, CO2: 1316.03
# Published data - Temperature: 14.70, Humidity: 3.13, CO2: 1414.70
# Published data - Temperature: 20.67, Humidity: 63.05, CO2: 1452.89
# Published data - Temperature: 22.06, Humidity: 2.28, CO2: 1802.39
# Published data - Temperature: -45.17, Humidity: 23.14, CO2: 1611.88
# Published data - Temperature: 33.76, Humidity: 61.16, CO2: 1350.60
# Published data - Temperature: -37.04, Humidity: 12.61, CO2: 1112.03
# Published data - Temperature: -41.81, Humidity: 21.54, CO2: 1596.31
# Published data - Temperature: -27.96, Humidity: 82.55, CO2: 1165.87
# Published data - Temperature: 34.58, Humidity: 41.52, CO2: 1188.06
# Published data - Temperature: -14.74, Humidity: 25.96, CO2: 637.39
# Published data - Temperature: -23.57, Humidity: 81.42, CO2: 1656.22
# Published data - Temperature: 2.53, Humidity: 98.86, CO2: 569.44
# Published data - Temperature: 16.56, Humidity: 60.91, CO2: 1256.03
# Sensor simulation stopped.
